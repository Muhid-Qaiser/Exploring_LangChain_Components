# %% [markdown]
# Created by Muhid Qaiser
#
# Email : muhidqaiser02@gmail.com
#
# Linkedin : https://www.linkedin.com/in/muhid-qaiser/
#
# Github : https://github.com/Muhid-Qaiser

# %% [markdown]
# # Splitting Json Data into Chunks using

# %%
import json
import requests

api_url="https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd"

json_data = requests.get(api_url).json()
json_data
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/1/large/bitcoin.png?1696501400',
#   'current_price': 87326,
#   'market_cap': 1734666709251,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 1734666709251,
#   'total_volume': 30331812936,
#   'high_24h': 88430,
#   'low_24h': 86358,
#   'price_change_24h': -58.09211586951278,
#   'price_change_percentage_24h': -0.06648,
#   'market_cap_change_24h': -1343300292.4060059,
#   'market_cap_change_percentage_24h': -0.07738,
#   'circulating_supply': 19841981.0,
#   'total_supply': 19841981.0,
#   'max_supply': 21000000.0,
#   'ath': 108786,
#   'ath_change_percentage': -19.60573,
#   'ath_date': '2025-01-20T09:11:54.494Z',
#   'atl': 67.81,
#   'atl_change_percentage': 128876.00034,
#   'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:33.113Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
#   'image': 'https://coin-images.coingecko.com/coins/images/279/large/ethereum.png?1696501628',
#   'current_price': 2064.24,
#   'market_cap': 249302696302,
#   'market_cap_rank': 2,
#   'fully_diluted_valuation': 249302696302,
#   'total_volume': 12453182913,
#   'high_24h': 2094.97,
#   'low_24h': 2042.48,
#   'price_change_24h': -21.987934237029094,
#   'price_change_percentage_24h': -1.05396,
#   'market_cap_change_24h': -1458326946.8786926,
#   'market_cap_change_percentage_24h': -0.58156,
#   'circulating_supply': 120641812.2610994,
#   'total_supply': 120641812.2610994,
#   'max_supply': None,
#   'ath': 4878.26,
#   'ath_change_percentage': -57.61583,
#   'ath_date': '2021-11-10T14:24:19.604Z',
#   'atl': 0.432979,
#   'atl_change_percentage': 477431.43516,
#   'atl_date': '2015-10-20T00:00:00.000Z',
#   'roi': {'times': 30.606947826883374,
#    'currency': 'btc',
#    'percentage': 3060.6947826883375},
#   'last_updated': '2025-03-26T00:13:28.145Z'},
#  {'id': 'tether',
#   'symbol': 'usdt',
#   'name': 'Tether',
#   'image': 'https://coin-images.coingecko.com/coins/images/325/large/Tether.png?1696501661',
#   'current_price': 1.0,
#   'market_cap': 143801842007,
#   'market_cap_rank': 3,
#   'fully_diluted_valuation': 143801842007,
#   'total_volume': 27597690843,
#   'high_24h': 1.0,
#   'low_24h': 1.0,
#   'price_change_24h': 2.43543e-07,
#   'price_change_percentage_24h': 2e-05,
#   'market_cap_change_24h': -872134.4116210938,
#   'market_cap_change_percentage_24h': -0.00061,
#   'circulating_supply': 143778115476.1538,
#   'total_supply': 143778115476.1538,
#   'max_supply': None,
#   'ath': 1.32,
#   'ath_change_percentage': -24.40716,
#   'ath_date': '2018-07-24T00:00:00.000Z',
#   'atl': 0.572521,
#   'atl_change_percentage': 74.69495,
#   'atl_date': '2015-03-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:31.283Z'},
#  {'id': 'ripple',
#   'symbol': 'xrp',
#   'name': 'XRP',
#   'image': 'https://coin-images.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1696501442',
#   'current_price': 2.45,
#   'market_cap': 142482600426,
#   'market_cap_rank': 4,
#   'fully_diluted_valuation': 244958286553,
#   'total_volume': 2324009245,
#   'high_24h': 2.47,
#   'low_24h': 2.41,
#   'price_change_24h': -0.005842325330859488,
#   'price_change_percentage_24h': -0.23818,
#   'market_cap_change_24h': -3027026.7386779785,
#   'market_cap_change_percentage_24h': -0.00212,
#   'circulating_supply': 58158111605.0,
#   'total_supply': 99986323420.0,
#   'max_supply': 100000000000.0,
#   'ath': 3.4,
#   'ath_change_percentage': -27.88109,
#   'ath_date': '2018-01-07T00:00:00.000Z',
#   'atl': 0.00268621,
#   'atl_change_percentage': 91141.12086,
#   'atl_date': '2014-05-22T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:34.546Z'},
#  {'id': 'binancecoin',
#   'symbol': 'bnb',
#   'name': 'BNB',
#   'image': 'https://coin-images.coingecko.com/coins/images/825/large/bnb-icon2_2x.png?1696501970',
#   'current_price': 629.48,
#   'market_cap': 91874606802,
#   'market_cap_rank': 5,
#   'fully_diluted_valuation': 91874606802,
#   'total_volume': 1580739863,
#   'high_24h': 644.81,
#   'low_24h': 626.52,
#   'price_change_24h': -9.829653235149408,
#   'price_change_percentage_24h': -1.53755,
#   'market_cap_change_24h': -1079473135.1636658,
#   'market_cap_change_percentage_24h': -1.1613,
#   'circulating_supply': 145887575.79,
#   'total_supply': 145887575.79,
#   'max_supply': 200000000.0,
#   'ath': 788.84,
#   'ath_change_percentage': -20.14498,
#   'ath_date': '2024-12-04T10:35:25.220Z',
#   'atl': 0.0398177,
#   'atl_change_percentage': 1581938.36036,
#   'atl_date': '2017-10-19T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:21.007Z'},
#  {'id': 'solana',
#   'symbol': 'sol',
#   'name': 'Solana',
#   'image': 'https://coin-images.coingecko.com/coins/images/4128/large/solana.png?1718769756',
#   'current_price': 143.45,
#   'market_cap': 73464235113,
#   'market_cap_rank': 6,
#   'fully_diluted_valuation': 85741442087,
#   'total_volume': 4198932807,
#   'high_24h': 147.2,
#   'low_24h': 138.45,
#   'price_change_24h': 2.51,
#   'price_change_percentage_24h': 1.77814,
#   'market_cap_change_24h': 1449053697,
#   'market_cap_change_percentage_24h': 2.01215,
#   'circulating_supply': 511462937.944055,
#   'total_supply': 596937677.3091404,
#   'max_supply': None,
#   'ath': 293.31,
#   'ath_change_percentage': -51.00831,
#   'ath_date': '2025-01-19T11:15:27.957Z',
#   'atl': 0.500801,
#   'atl_change_percentage': 28593.72014,
#   'atl_date': '2020-05-11T19:35:23.449Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:35.397Z'},
#  {'id': 'usd-coin',
#   'symbol': 'usdc',
#   'name': 'USDC',
#   'image': 'https://coin-images.coingecko.com/coins/images/6319/large/usdc.png?1696506694',
#   'current_price': 0.999895,
#   'market_cap': 60050706610,
#   'market_cap_rank': 7,
#   'fully_diluted_valuation': 60115129804,
#   'total_volume': 5112600571,
#   'high_24h': 0.99992,
#   'low_24h': 0.99979,
#   'price_change_24h': 5.964e-05,
#   'price_change_percentage_24h': 0.00596,
#   'market_cap_change_24h': 352906433,
#   'market_cap_change_percentage_24h': 0.59115,
#   'circulating_supply': 60059556549.53757,
#   'total_supply': 60123989238.32883,
#   'max_supply': None,
#   'ath': 1.17,
#   'ath_change_percentage': -14.74429,
#   'ath_date': '2019-05-08T00:40:28.300Z',
#   'atl': 0.877647,
#   'atl_change_percentage': 13.91816,
#   'atl_date': '2023-03-11T08:02:13.981Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:33.868Z'},
#  {'id': 'dogecoin',
#   'symbol': 'doge',
#   'name': 'Dogecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/5/large/dogecoin.png?1696501409',
#   'current_price': 0.189957,
#   'market_cap': 28343610320,
#   'market_cap_rank': 8,
#   'fully_diluted_valuation': 28344402002,
#   'total_volume': 1684438867,
#   'high_24h': 0.193022,
#   'low_24h': 0.181563,
#   'price_change_24h': 0.00670902,
#   'price_change_percentage_24h': 3.66118,
#   'market_cap_change_24h': 1182849535,
#   'market_cap_change_percentage_24h': 4.35499,
#   'circulating_supply': 148577206383.7052,
#   'total_supply': 148581356383.7052,
#   'max_supply': None,
#   'ath': 0.731578,
#   'ath_change_percentage': -73.91432,
#   'ath_date': '2021-05-08T05:08:23.458Z',
#   'atl': 8.69e-05,
#   'atl_change_percentage': 219495.9483,
#   'atl_date': '2015-05-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:25.983Z'},
#  {'id': 'cardano',
#   'symbol': 'ada',
#   'name': 'Cardano',
#   'image': 'https://coin-images.coingecko.com/coins/images/975/large/cardano.png?1696502090',
#   'current_price': 0.743381,
#   'market_cap': 26801994962,
#   'market_cap_rank': 9,
#   'fully_diluted_valuation': 33520783411,
#   'total_volume': 1095750147,
#   'high_24h': 0.76442,
#   'low_24h': 0.722566,
#   'price_change_24h': 0.01135364,
#   'price_change_percentage_24h': 1.55099,
#   'market_cap_change_24h': 489188513,
#   'market_cap_change_percentage_24h': 1.85913,
#   'circulating_supply': 35980357573.51544,
#   'total_supply': 45000000000.0,
#   'max_supply': 45000000000.0,
#   'ath': 3.09,
#   'ath_change_percentage': -75.85988,
#   'ath_date': '2021-09-02T06:00:10.474Z',
#   'atl': 0.01925275,
#   'atl_change_percentage': 3770.53409,
#   'atl_date': '2020-03-13T02:22:55.044Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:24.052Z'},
#  {'id': 'tron',
#   'symbol': 'trx',
#   'name': 'TRON',
#   'image': 'https://coin-images.coingecko.com/coins/images/1094/large/tron-logo.png?1696502193',
#   'current_price': 0.227028,
#   'market_cap': 21573833071,
#   'market_cap_rank': 10,
#   'fully_diluted_valuation': 21573853517,
#   'total_volume': 423375550,
#   'high_24h': 0.229454,
#   'low_24h': 0.226008,
#   'price_change_24h': -0.000879443217096959,
#   'price_change_percentage_24h': -0.38588,
#   'market_cap_change_24h': -105768070.69986343,
#   'market_cap_change_percentage_24h': -0.48787,
#   'circulating_supply': 95003693184.17773,
#   'total_supply': 95003783220.1161,
#   'max_supply': None,
#   'ath': 0.431288,
#   'ath_change_percentage': -47.31302,
#   'ath_date': '2024-12-04T00:10:40.323Z',
#   'atl': 0.00180434,
#   'atl_change_percentage': 12493.66981,
#   'atl_date': '2017-11-12T00:00:00.000Z',
#   'roi': {'times': 118.4881677938621,
#    'currency': 'usd',
#    'percentage': 11848.81677938621},
#   'last_updated': '2025-03-26T00:13:33.839Z'},
#  {'id': 'staked-ether',
#   'symbol': 'steth',
#   'name': 'Lido Staked Ether',
#   'image': 'https://coin-images.coingecko.com/coins/images/13442/large/steth_logo.png?1696513206',
#   'current_price': 2063.97,
#   'market_cap': 19313528824,
#   'market_cap_rank': 11,
#   'fully_diluted_valuation': 19313715894,
#   'total_volume': 11096903,
#   'high_24h': 2091.18,
#   'low_24h': 2039.5,
#   'price_change_24h': -14.39679649565278,
#   'price_change_percentage_24h': -0.6927,
#   'market_cap_change_24h': -90907631.54468918,
#   'market_cap_change_percentage_24h': -0.46849,
#   'circulating_supply': 9348221.443801891,
#   'total_supply': 9348311.990061846,
#   'max_supply': None,
#   'ath': 4829.57,
#   'ath_change_percentage': -57.24315,
#   'ath_date': '2021-11-10T14:40:47.256Z',
#   'atl': 482.9,
#   'atl_change_percentage': 327.62239,
#   'atl_date': '2020-12-22T04:08:21.854Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:34.774Z'},
#  {'id': 'wrapped-bitcoin',
#   'symbol': 'wbtc',
#   'name': 'Wrapped Bitcoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/7598/large/wrapped_bitcoin_wbtc.png?1696507857',
#   'current_price': 87220,
#   'market_cap': 11269673554,
#   'market_cap_rank': 12,
#   'fully_diluted_valuation': 11269673554,
#   'total_volume': 280154995,
#   'high_24h': 88386,
#   'low_24h': 86236,
#   'price_change_24h': -42.517766236676835,
#   'price_change_percentage_24h': -0.04872,
#   'market_cap_change_24h': 27867537,
#   'market_cap_change_percentage_24h': 0.24789,
#   'circulating_supply': 128915.05657878,
#   'total_supply': 128915.05657878,
#   'max_supply': 128915.05657878,
#   'ath': 108368,
#   'ath_change_percentage': -19.30723,
#   'ath_date': '2025-01-20T07:16:27.137Z',
#   'atl': 3139.17,
#   'atl_change_percentage': 2685.60711,
#   'atl_date': '2019-04-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:31.505Z'},
#  {'id': 'chainlink',
#   'symbol': 'link',
#   'name': 'Chainlink',
#   'image': 'https://coin-images.coingecko.com/coins/images/877/large/chainlink-new-logo.png?1696502009',
#   'current_price': 15.41,
#   'market_cap': 9850634724,
#   'market_cap_rank': 13,
#   'fully_diluted_valuation': 15437447367,
#   'total_volume': 396656922,
#   'high_24h': 15.58,
#   'low_24h': 14.89,
#   'price_change_24h': 0.291656,
#   'price_change_percentage_24h': 1.92864,
#   'market_cap_change_24h': 214084065,
#   'market_cap_change_percentage_24h': 2.22158,
#   'circulating_supply': 638099971.4505637,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 52.7,
#   'ath_change_percentage': -70.68762,
#   'ath_date': '2021-05-10T00:13:57.214Z',
#   'atl': 0.148183,
#   'atl_change_percentage': 10324.00596,
#   'atl_date': '2017-11-29T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:24.601Z'},
#  {'id': 'avalanche-2',
#   'symbol': 'avax',
#   'name': 'Avalanche',
#   'image': 'https://coin-images.coingecko.com/coins/images/12559/large/Avalanche_Circle_RedWhite_Trans.png?1696512369',
#   'current_price': 22.97,
#   'market_cap': 9520395200,
#   'market_cap_rank': 14,
#   'fully_diluted_valuation': 10362020904,
#   'total_volume': 390650499,
#   'high_24h': 23.41,
#   'low_24h': 21.33,
#   'price_change_24h': 1.45,
#   'price_change_percentage_24h': 6.74242,
#   'market_cap_change_24h': 618874099,
#   'market_cap_change_percentage_24h': 6.95245,
#   'circulating_supply': 414790828.9956329,
#   'total_supply': 451459330.2512311,
#   'max_supply': 720000000.0,
#   'ath': 144.96,
#   'ath_change_percentage': -84.19052,
#   'ath_date': '2021-11-21T14:18:56.538Z',
#   'atl': 2.8,
#   'atl_change_percentage': 718.17511,
#   'atl_date': '2020-12-31T13:15:21.540Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:35.338Z'},
#  {'id': 'stellar',
#   'symbol': 'xlm',
#   'name': 'Stellar',
#   'image': 'https://coin-images.coingecko.com/coins/images/100/large/fmpFRHHQ_400x400.jpg?1735231350',
#   'current_price': 0.293756,
#   'market_cap': 9044264090,
#   'market_cap_rank': 15,
#   'fully_diluted_valuation': 14692073210,
#   'total_volume': 174557461,
#   'high_24h': 0.295185,
#   'low_24h': 0.286547,
#   'price_change_24h': 0.00195614,
#   'price_change_percentage_24h': 0.67037,
#   'market_cap_change_24h': 101125060,
#   'market_cap_change_percentage_24h': 1.13076,
#   'circulating_supply': 30780500419.99179,
#   'total_supply': 50001786892.81798,
#   'max_supply': 50001786892.81798,
#   'ath': 0.875563,
#   'ath_change_percentage': -66.44064,
#   'ath_date': '2018-01-03T00:00:00.000Z',
#   'atl': 0.00047612,
#   'atl_change_percentage': 61613.70329,
#   'atl_date': '2015-03-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:34.813Z'},
#  {'id': 'leo-token',
#   'symbol': 'leo',
#   'name': 'LEO Token',
#   'image': 'https://coin-images.coingecko.com/coins/images/8418/large/leo-token.png?1696508607',
#   'current_price': 9.77,
#   'market_cap': 9034503183,
#   'market_cap_rank': 16,
#   'fully_diluted_valuation': 9634633017,
#   'total_volume': 3779749,
#   'high_24h': 9.81,
#   'low_24h': 9.75,
#   'price_change_24h': 0.01279817,
#   'price_change_percentage_24h': 0.13112,
#   'market_cap_change_24h': -2466161.2147102356,
#   'market_cap_change_percentage_24h': -0.02729,
#   'circulating_supply': 923870106.9,
#   'total_supply': 985239504.0,
#   'max_supply': None,
#   'ath': 10.14,
#   'ath_change_percentage': -3.48554,
#   'ath_date': '2025-03-10T09:26:43.294Z',
#   'atl': 0.799859,
#   'atl_change_percentage': 1122.94609,
#   'atl_date': '2019-12-24T15:14:35.376Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:30.688Z'},
#  {'id': 'the-open-network',
#   'symbol': 'ton',
#   'name': 'Toncoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/17980/large/photo_2024-09-10_17.09.00.jpeg?1725963446',
#   'current_price': 3.6,
#   'market_cap': 8926671879,
#   'market_cap_rank': 17,
#   'fully_diluted_valuation': 18432018531,
#   'total_volume': 141501095,
#   'high_24h': 3.69,
#   'low_24h': 3.56,
#   'price_change_24h': -0.062348199251339054,
#   'price_change_percentage_24h': -1.70353,
#   'market_cap_change_24h': -169225429.22750473,
#   'market_cap_change_percentage_24h': -1.86046,
#   'circulating_supply': 2482329305.696961,
#   'total_supply': 5125576517.750345,
#   'max_supply': None,
#   'ath': 8.25,
#   'ath_change_percentage': -56.46206,
#   'ath_date': '2024-06-15T00:36:51.509Z',
#   'atl': 0.519364,
#   'atl_change_percentage': 591.89469,
#   'atl_date': '2021-09-21T00:33:11.092Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:36.020Z'},
#  {'id': 'wrapped-steth',
#   'symbol': 'wsteth',
#   'name': 'Wrapped stETH',
#   'image': 'https://coin-images.coingecko.com/coins/images/18834/large/wstETH.png?1696518295',
#   'current_price': 2470.76,
#   'market_cap': 8867726030,
#   'market_cap_rank': 18,
#   'fully_diluted_valuation': 8867726030,
#   'total_volume': 8784136,
#   'high_24h': 2505.12,
#   'low_24h': 2446.59,
#   'price_change_24h': -21.748857654906715,
#   'price_change_percentage_24h': -0.87257,
#   'market_cap_change_24h': -88791781.41870117,
#   'market_cap_change_percentage_24h': -0.99136,
#   'circulating_supply': 3586771.320588108,
#   'total_supply': 3586771.320588108,
#   'max_supply': None,
#   'ath': 7256.02,
#   'ath_change_percentage': -65.92703,
#   'ath_date': '2022-05-13T15:09:54.509Z',
#   'atl': 558.54,
#   'atl_change_percentage': 342.64353,
#   'atl_date': '2022-05-13T01:36:45.053Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:30.624Z'},
#  {'id': 'usds',
#   'symbol': 'usds',
#   'name': 'USDS',
#   'image': 'https://coin-images.coingecko.com/coins/images/39926/large/usds.webp?1726666683',
#   'current_price': 0.999644,
#   'market_cap': 8281174994,
#   'market_cap_rank': 19,
#   'fully_diluted_valuation': 8281174994,
#   'total_volume': 17419665,
#   'high_24h': 1.001,
#   'low_24h': 0.998664,
#   'price_change_24h': 0.00039754,
#   'price_change_percentage_24h': 0.03978,
#   'market_cap_change_24h': -56407874.85326004,
#   'market_cap_change_percentage_24h': -0.67655,
#   'circulating_supply': 8281339305.377656,
#   'total_supply': 8281339305.377656,
#   'max_supply': None,
#   'ath': 1.057,
#   'ath_change_percentage': -5.45354,
#   'ath_date': '2024-10-29T05:40:51.197Z',
#   'atl': 0.948265,
#   'atl_change_percentage': 5.41996,
#   'atl_date': '2024-10-03T13:19:28.826Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:29.902Z'},
#  {'id': 'hedera-hashgraph',
#   'symbol': 'hbar',
#   'name': 'Hedera',
#   'image': 'https://coin-images.coingecko.com/coins/images/3688/large/hbar.png?1696504364',
#   'current_price': 0.194523,
#   'market_cap': 8224000876,
#   'market_cap_rank': 20,
#   'fully_diluted_valuation': 9739599535,
#   'total_volume': 218994896,
#   'high_24h': 0.200937,
#   'low_24h': 0.191332,
#   'price_change_24h': 0.00086171,
#   'price_change_percentage_24h': 0.44496,
#   'market_cap_change_24h': 72833004,
#   'market_cap_change_percentage_24h': 0.89353,
#   'circulating_supply': 42219399509.38537,
#   'total_supply': 50000000000.0,
#   'max_supply': 50000000000.0,
#   'ath': 0.569229,
#   'ath_change_percentage': -65.77967,
#   'ath_date': '2021-09-15T10:40:28.318Z',
#   'atl': 0.00986111,
#   'atl_change_percentage': 1875.35554,
#   'atl_date': '2020-01-02T17:30:24.852Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:28.853Z'},
#  {'id': 'shiba-inu',
#   'symbol': 'shib',
#   'name': 'Shiba Inu',
#   'image': 'https://coin-images.coingecko.com/coins/images/11939/large/shiba.png?1696511800',
#   'current_price': 1.383e-05,
#   'market_cap': 8150618573,
#   'market_cap_rank': 21,
#   'fully_diluted_valuation': 8154130946,
#   'total_volume': 211685153,
#   'high_24h': 1.396e-05,
#   'low_24h': 1.338e-05,
#   'price_change_24h': 2.55258e-07,
#   'price_change_percentage_24h': 1.88015,
#   'market_cap_change_24h': 170351299,
#   'market_cap_change_percentage_24h': 2.13466,
#   'circulating_supply': 589251861012579.1,
#   'total_supply': 589505789286720.6,
#   'max_supply': None,
#   'ath': 8.616e-05,
#   'ath_change_percentage': -83.90819,
#   'ath_date': '2021-10-28T03:54:55.568Z',
#   'atl': 5.6366e-11,
#   'atl_change_percentage': 24597027.75968,
#   'atl_date': '2020-11-28T11:26:25.838Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:34.770Z'},
#  {'id': 'sui',
#   'symbol': 'sui',
#   'name': 'Sui',
#   'image': 'https://coin-images.coingecko.com/coins/images/26375/large/sui-ocean-square.png?1727791290',
#   'current_price': 2.45,
#   'market_cap': 7793873862,
#   'market_cap_rank': 22,
#   'fully_diluted_valuation': 24587554739,
#   'total_volume': 741117694,
#   'high_24h': 2.48,
#   'low_24h': 2.34,
#   'price_change_24h': 0.05793,
#   'price_change_percentage_24h': 2.41806,
#   'market_cap_change_24h': 207824756,
#   'market_cap_change_percentage_24h': 2.73957,
#   'circulating_supply': 3169845047.483887,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 5.35,
#   'ath_change_percentage': -54.08234,
#   'ath_date': '2025-01-04T22:56:18.063Z',
#   'atl': 0.364846,
#   'atl_change_percentage': 572.89116,
#   'atl_date': '2023-10-19T10:40:30.078Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:29.996Z'},
#  {'id': 'litecoin',
#   'symbol': 'ltc',
#   'name': 'Litecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/2/large/litecoin.png?1696501400',
#   'current_price': 94.53,
#   'market_cap': 7146158885,
#   'market_cap_rank': 23,
#   'fully_diluted_valuation': 7146259812,
#   'total_volume': 397671313,
#   'high_24h': 94.65,
#   'low_24h': 92.07,
#   'price_change_24h': 0.71955,
#   'price_change_percentage_24h': 0.767,
#   'market_cap_change_24h': 58529449,
#   'market_cap_change_percentage_24h': 0.8258,
#   'circulating_supply': 75673276.98347135,
#   'total_supply': 75674345.73347135,
#   'max_supply': 84000000.0,
#   'ath': 410.26,
#   'ath_change_percentage': -76.97368,
#   'ath_date': '2021-05-10T03:13:07.904Z',
#   'atl': 1.15,
#   'atl_change_percentage': 8122.8628,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:32.315Z'},
#  {'id': 'polkadot',
#   'symbol': 'dot',
#   'name': 'Polkadot',
#   'image': 'https://coin-images.coingecko.com/coins/images/12171/large/polkadot.png?1696512008',
#   'current_price': 4.63,
#   'market_cap': 7043594883,
#   'market_cap_rank': 24,
#   'fully_diluted_valuation': 7043594883,
#   'total_volume': 149806847,
#   'high_24h': 4.72,
#   'low_24h': 4.59,
#   'price_change_24h': -0.001780886132481285,
#   'price_change_percentage_24h': -0.03848,
#   'market_cap_change_24h': 15803523,
#   'market_cap_change_percentage_24h': 0.22487,
#   'circulating_supply': 1522267060.0,
#   'total_supply': 1522267060.0,
#   'max_supply': None,
#   'ath': 54.98,
#   'ath_change_percentage': -91.56696,
#   'ath_date': '2021-11-04T14:10:09.301Z',
#   'atl': 2.7,
#   'atl_change_percentage': 71.88649,
#   'atl_date': '2020-08-20T05:48:11.359Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:34.112Z'},
#  {'id': 'mantra-dao',
#   'symbol': 'om',
#   'name': 'MANTRA',
#   'image': 'https://coin-images.coingecko.com/coins/images/12151/large/OM_Token.png?1696511991',
#   'current_price': 6.83,
#   'market_cap': 6735303221,
#   'market_cap_rank': 25,
#   'fully_diluted_valuation': 12391203969,
#   'total_volume': 77569197,
#   'high_24h': 6.85,
#   'low_24h': 6.64,
#   'price_change_24h': 0.0050979,
#   'price_change_percentage_24h': 0.07466,
#   'market_cap_change_24h': 2412438,
#   'market_cap_change_percentage_24h': 0.03583,
#   'circulating_supply': 985683397.8799999,
#   'total_supply': 1813400767.68,
#   'max_supply': None,
#   'ath': 8.99,
#   'ath_change_percentage': -24.14695,
#   'ath_date': '2025-02-23T01:52:21.073Z',
#   'atl': 0.01726188,
#   'atl_change_percentage': 39383.96172,
#   'atl_date': '2023-10-12T17:25:09.068Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:31.294Z'},
#  {'id': 'bitcoin-cash',
#   'symbol': 'bch',
#   'name': 'Bitcoin Cash',
#   'image': 'https://coin-images.coingecko.com/coins/images/780/large/bitcoin-cash-circle.png?1696501932',
#   'current_price': 336.34,
#   'market_cap': 6665008664,
#   'market_cap_rank': 26,
#   'fully_diluted_valuation': 6665016010,
#   'total_volume': 161740726,
#   'high_24h': 338.61,
#   'low_24h': 327.1,
#   'price_change_24h': 3.62,
#   'price_change_percentage_24h': 1.08859,
#   'market_cap_change_24h': 66968762,
#   'market_cap_change_percentage_24h': 1.01498,
#   'circulating_supply': 19847053.02165078,
#   'total_supply': 19847074.89665078,
#   'max_supply': 21000000.0,
#   'ath': 3785.82,
#   'ath_change_percentage': -91.13326,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 76.93,
#   'atl_change_percentage': 336.31575,
#   'atl_date': '2018-12-16T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:23.727Z'},
#  {'id': 'bitget-token',
#   'symbol': 'bgb',
#   'name': 'Bitget Token',
#   'image': 'https://coin-images.coingecko.com/coins/images/11610/large/Bitget_logo.png?1736925727',
#   'current_price': 4.96,
#   'market_cap': 5943602412,
#   'market_cap_rank': 27,
#   'fully_diluted_valuation': 5943602412,
#   'total_volume': 141414480,
#   'high_24h': 4.99,
#   'low_24h': 4.81,
#   'price_change_24h': 0.064994,
#   'price_change_percentage_24h': 1.32834,
#   'market_cap_change_24h': 67746238,
#   'market_cap_change_percentage_24h': 1.15296,
#   'circulating_supply': 1199999994.2,
#   'total_supply': 1199999994.2,
#   'max_supply': 2000000000.0,
#   'ath': 8.45,
#   'ath_change_percentage': -41.35995,
#   'ath_date': '2024-12-27T11:41:24.992Z',
#   'atl': 0.0142795,
#   'atl_change_percentage': 34602.01078,
#   'atl_date': '2020-06-25T04:17:05.895Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:35.550Z'},
#  {'id': 'pi-network',
#   'symbol': 'pi',
#   'name': 'Pi Network',
#   'image': 'https://coin-images.coingecko.com/coins/images/54342/large/pi_network.jpg?1739347576',
#   'current_price': 0.869791,
#   'market_cap': 5906014032,
#   'market_cap_rank': 28,
#   'fully_diluted_valuation': 9086175434,
#   'total_volume': 216232763,
#   'high_24h': 0.942972,
#   'low_24h': 0.857524,
#   'price_change_24h': -0.07251730159166847,
#   'price_change_percentage_24h': -7.69571,
#   'market_cap_change_24h': -467923141.18416595,
#   'market_cap_change_percentage_24h': -7.34119,
#   'circulating_supply': 6763876079.296083,
#   'total_supply': 10405963198.91705,
#   'max_supply': 100000000000.0,
#   'ath': 2.99,
#   'ath_change_percentage': -70.88033,
#   'ath_date': '2025-02-26T16:41:03.732Z',
#   'atl': 0.615725,
#   'atl_change_percentage': 41.29409,
#   'atl_date': '2025-02-20T18:06:42.957Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:32.506Z'},
#  {'id': 'weth',
#   'symbol': 'weth',
#   'name': 'WETH',
#   'image': 'https://coin-images.coingecko.com/coins/images/2518/large/weth.png?1696503332',
#   'current_price': 2062.48,
#   'market_cap': 5826817551,
#   'market_cap_rank': 29,
#   'fully_diluted_valuation': 5826817551,
#   'total_volume': 42814769,
#   'high_24h': 2094.21,
#   'low_24h': 2042.1,
#   'price_change_24h': -24.109270189497693,
#   'price_change_percentage_24h': -1.15544,
#   'market_cap_change_24h': 11270303,
#   'market_cap_change_percentage_24h': 0.1938,
#   'circulating_supply': 2819924.075374875,
#   'total_supply': 2819924.075374875,
#   'max_supply': None,
#   'ath': 4799.89,
#   'ath_change_percentage': -56.90903,
#   'ath_date': '2021-11-09T00:00:00.000Z',
#   'atl': 82.1,
#   'atl_change_percentage': 2419.16509,
#   'atl_date': '2018-12-15T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:33.369Z'},
#  {'id': 'ethena-usde',
#   'symbol': 'usde',
#   'name': 'Ethena USDe',
#   'image': 'https://coin-images.coingecko.com/coins/images/33613/large/usde.png?1733810059',
#   'current_price': 0.99928,
#   'market_cap': 5372374041,
#   'market_cap_rank': 30,
#   'fully_diluted_valuation': 5372374041,
#   'total_volume': 57465418,
#   'high_24h': 1.0,
#   'low_24h': 0.998597,
#   'price_change_24h': -0.000709070652100574,
#   'price_change_percentage_24h': -0.07091,
#   'market_cap_change_24h': -4181836.059577942,
#   'market_cap_change_percentage_24h': -0.07778,
#   'circulating_supply': 5376247112.771086,
#   'total_supply': 5376247112.771086,
#   'max_supply': None,
#   'ath': 1.032,
#   'ath_change_percentage': -3.13588,
#   'ath_date': '2023-12-20T15:38:34.596Z',
#   'atl': 0.929486,
#   'atl_change_percentage': 7.55592,
#   'atl_date': '2024-10-04T07:57:15.809Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:25.553Z'},
#  {'id': 'hyperliquid',
#   'symbol': 'hype',
#   'name': 'Hyperliquid',
#   'image': 'https://coin-images.coingecko.com/coins/images/50882/large/hyperliquid.jpg?1729431300',
#   'current_price': 15.99,
#   'market_cap': 5347528856,
#   'market_cap_rank': 31,
#   'fully_diluted_valuation': 16013855050,
#   'total_volume': 82341032,
#   'high_24h': 16.95,
#   'low_24h': 15.94,
#   'price_change_24h': -0.6464389736409153,
#   'price_change_percentage_24h': -3.88632,
#   'market_cap_change_24h': -238643385.7374401,
#   'market_cap_change_percentage_24h': -4.27204,
#   'circulating_supply': 333928180.0,
#   'total_supply': 999990391.0,
#   'max_supply': 1000000000.0,
#   'ath': 34.96,
#   'ath_change_percentage': -54.25677,
#   'ath_date': '2024-12-22T03:56:00.276Z',
#   'atl': 3.81,
#   'atl_change_percentage': 319.86383,
#   'atl_date': '2024-11-29T09:30:30.871Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:29.073Z'},
#  {'id': 'binance-bridged-usdt-bnb-smart-chain',
#   'symbol': 'bsc-usd',
#   'name': 'Binance Bridged USDT (BNB Smart Chain)',
#   'image': 'https://coin-images.coingecko.com/coins/images/35021/large/USDT.png?1707233575',
#   'current_price': 1.0,
#   'market_cap': 5184149893,
#   'market_cap_rank': 32,
#   'fully_diluted_valuation': 5184149893,
#   'total_volume': 245363134,
#   'high_24h': 1.003,
#   'low_24h': 0.997307,
#   'price_change_24h': 0.000321,
#   'price_change_percentage_24h': 0.0321,
#   'market_cap_change_24h': -2216506.456974983,
#   'market_cap_change_percentage_24h': -0.04274,
#   'circulating_supply': 5184994501.618546,
#   'total_supply': 5184994501.618546,
#   'max_supply': None,
#   'ath': 1.05,
#   'ath_change_percentage': -4.72097,
#   'ath_date': '2024-08-05T14:21:42.527Z',
#   'atl': 0.942186,
#   'atl_change_percentage': 6.17785,
#   'atl_date': '2024-12-05T22:30:39.827Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:36.245Z'},
#  {'id': 'wrapped-eeth',
#   'symbol': 'weeth',
#   'name': 'Wrapped eETH',
#   'image': 'https://coin-images.coingecko.com/coins/images/33033/large/weETH.png?1701438396',
#   'current_price': 2194.62,
#   'market_cap': 4596789590,
#   'market_cap_rank': 33,
#   'fully_diluted_valuation': 4596789590,
#   'total_volume': 7750652,
#   'high_24h': 2224.4,
#   'low_24h': 2171.19,
#   'price_change_24h': -22.338753873605583,
#   'price_change_percentage_24h': -1.00763,
#   'market_cap_change_24h': -30458291.69538021,
#   'market_cap_change_percentage_24h': -0.65824,
#   'circulating_supply': 2093089.778860503,
#   'total_supply': 2093089.778860503,
#   'max_supply': None,
#   'ath': 4311.81,
#   'ath_change_percentage': -49.06585,
#   'ath_date': '2024-12-06T20:32:25.758Z',
#   'atl': 1889.13,
#   'atl_change_percentage': 16.25368,
#   'atl_date': '2025-03-11T00:55:51.837Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:30.293Z'},
#  {'id': 'whitebit',
#   'symbol': 'wbt',
#   'name': 'WhiteBIT Coin',
#   'image': 'https://coin-images.coingecko.com/coins/images/27045/large/wbt_token.png?1696526096',
#   'current_price': 29.15,
#   'market_cap': 4203129488,
#   'market_cap_rank': 34,
#   'fully_diluted_valuation': 9577032378,
#   'total_volume': 21062332,
#   'high_24h': 29.42,
#   'low_24h': 29.06,
#   'price_change_24h': -0.06378873015838238,
#   'price_change_percentage_24h': -0.21838,
#   'market_cap_change_24h': -18142798.405694008,
#   'market_cap_change_percentage_24h': -0.42979,
#   'circulating_supply': 144118517.10815412,
#   'total_supply': 328380962.0,
#   'max_supply': 400000000.0,
#   'ath': 31.28,
#   'ath_change_percentage': -6.85634,
#   'ath_date': '2025-03-02T22:22:36.852Z',
#   'atl': 3.06,
#   'atl_change_percentage': 851.46984,
#   'atl_date': '2023-02-13T19:01:21.899Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:29.926Z'},
#  {'id': 'uniswap',
#   'symbol': 'uni',
#   'name': 'Uniswap',
#   'image': 'https://coin-images.coingecko.com/coins/images/12504/large/uniswap-logo.png?1720676669',
#   'current_price': 6.95,
#   'market_cap': 4174018170,
#   'market_cap_rank': 35,
#   'fully_diluted_valuation': 6951100460,
#   'total_volume': 109364179,
#   'high_24h': 7.12,
#   'low_24h': 6.93,
#   'price_change_24h': -0.13673518342793312,
#   'price_change_percentage_24h': -1.92909,
#   'market_cap_change_24h': -71405827.56118584,
#   'market_cap_change_percentage_24h': -1.68195,
#   'circulating_supply': 600483073.71,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 44.92,
#   'ath_change_percentage': -84.50886,
#   'ath_date': '2021-05-03T05:25:04.822Z',
#   'atl': 1.03,
#   'atl_change_percentage': 575.45279,
#   'atl_date': '2020-09-17T01:20:38.214Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:30.448Z'},
#  {'id': 'monero',
#   'symbol': 'xmr',
#   'name': 'Monero',
#   'image': 'https://coin-images.coingecko.com/coins/images/69/large/monero_logo.png?1696501460',
#   'current_price': 220.55,
#   'market_cap': 4055771620,
#   'market_cap_rank': 36,
#   'fully_diluted_valuation': 4055771620,
#   'total_volume': 70614369,
#   'high_24h': 225.04,
#   'low_24h': 218.6,
#   'price_change_24h': 0.580125,
#   'price_change_percentage_24h': 0.26373,
#   'market_cap_change_24h': 10023794,
#   'market_cap_change_percentage_24h': 0.24776,
#   'circulating_supply': 18446744.07370955,
#   'total_supply': 18446744.07370955,
#   'max_supply': None,
#   'ath': 542.33,
#   'ath_change_percentage': -59.47223,
#   'ath_date': '2018-01-09T00:00:00.000Z',
#   'atl': 0.216177,
#   'atl_change_percentage': 101572.60255,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:31.577Z'},
#  {'id': 'near',
#   'symbol': 'near',
#   'name': 'NEAR Protocol',
#   'image': 'https://coin-images.coingecko.com/coins/images/10365/large/near.jpg?1696510367',
#   'current_price': 3.03,
#   'market_cap': 3624265509,
#   'market_cap_rank': 37,
#   'fully_diluted_valuation': 3758648705,
#   'total_volume': 168168690,
#   'high_24h': 3.07,
#   'low_24h': 2.9,
#   'price_change_24h': 0.102333,
#   'price_change_percentage_24h': 3.49908,
#   'market_cap_change_24h': 124944031,
#   'market_cap_change_percentage_24h': 3.57052,
#   'circulating_supply': 1197455040.0,
#   'total_supply': 1241855163.0,
#   'max_supply': None,
#   'ath': 20.44,
#   'ath_change_percentage': -85.19322,
#   'ath_date': '2022-01-16T22:09:45.873Z',
#   'atl': 0.526762,
#   'atl_change_percentage': 474.49588,
#   'atl_date': '2020-11-04T16:09:15.137Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:32.219Z'},
#  {'id': 'aptos',
#   'symbol': 'apt',
#   'name': 'Aptos',
#   'image': 'https://coin-images.coingecko.com/coins/images/26455/large/aptos_round.png?1696525528',
#   'current_price': 5.92,
#   'market_cap': 3569628795,
#   'market_cap_rank': 38,
#   'fully_diluted_valuation': 6775886462,
#   'total_volume': 115232960,
#   'high_24h': 6.08,
#   'low_24h': 5.85,
#   'price_change_24h': -0.10936818609758969,
#   'price_change_percentage_24h': -1.81369,
#   'market_cap_change_24h': -71404395.68231201,
#   'market_cap_change_percentage_24h': -1.9611,
#   'circulating_supply': 603442596.2772886,
#   'total_supply': 1145457624.333073,
#   'max_supply': None,
#   'ath': 19.92,
#   'ath_change_percentage': -70.33373,
#   'ath_date': '2023-01-26T14:25:17.390Z',
#   'atl': 3.08,
#   'atl_change_percentage': 91.88411,
#   'atl_date': '2022-12-29T21:35:14.796Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:34.534Z'},
#  {'id': 'pepe',
#   'symbol': 'pepe',
#   'name': 'Pepe',
#   'image': 'https://coin-images.coingecko.com/coins/images/29850/large/pepe-token.jpeg?1696528776',
#   'current_price': 7.99e-06,
#   'market_cap': 3371822082,
#   'market_cap_rank': 39,
#   'fully_diluted_valuation': 3371822082,
#   'total_volume': 558747957,
#   'high_24h': 8.17e-06,
#   'low_24h': 7.85e-06,
#   'price_change_24h': -1.4615207732e-08,
#   'price_change_percentage_24h': -0.18263,
#   'market_cap_change_24h': 23353439,
#   'market_cap_change_percentage_24h': 0.69744,
#   'circulating_supply': 420690000000000.0,
#   'total_supply': 420690000000000.0,
#   'max_supply': 420690000000000.0,
#   'ath': 2.803e-05,
#   'ath_change_percentage': -71.43261,
#   'ath_date': '2024-12-09T16:30:35.828Z',
#   'atl': 5.5142e-08,
#   'atl_change_percentage': 14420.44351,
#   'atl_date': '2023-04-18T02:14:41.591Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:32.841Z'},
#  {'id': 'susds',
#   'symbol': 'susds',
#   'name': 'sUSDS',
#   'image': 'https://coin-images.coingecko.com/coins/images/52721/large/sUSDS_Coin.png?1734086971',
#   'current_price': 1.046,
#   'market_cap': 3275465737,
#   'market_cap_rank': 40,
#   'fully_diluted_valuation': 3275465737,
#   'total_volume': 2333541,
#   'high_24h': 1.048,
#   'low_24h': 1.041,
#   'price_change_24h': 0.0022251,
#   'price_change_percentage_24h': 0.21309,
#   'market_cap_change_24h': -82379554.2938385,
#   'market_cap_change_percentage_24h': -2.45335,
#   'circulating_supply': 3126579951.481181,
#   'total_supply': 3126579951.481181,
#   'max_supply': None,
#   'ath': 1.088,
#   'ath_change_percentage': -3.79411,
#   'ath_date': '2025-02-03T02:31:35.208Z',
#   'atl': 0.961716,
#   'atl_change_percentage': 8.83022,
#   'atl_date': '2025-01-04T01:21:08.460Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:34.830Z'},
#  {'id': 'dai',
#   'symbol': 'dai',
#   'name': 'Dai',
#   'image': 'https://coin-images.coingecko.com/coins/images/9956/large/Badge_Dai.png?1696509996',
#   'current_price': 0.999839,
#   'market_cap': 3266746943,
#   'market_cap_rank': 41,
#   'fully_diluted_valuation': 3266746943,
#   'total_volume': 104842238,
#   'high_24h': 1.0,
#   'low_24h': 0.999427,
#   'price_change_24h': 3.15e-05,
#   'price_change_percentage_24h': 0.00315,
#   'market_cap_change_24h': -7582114.611999035,
#   'market_cap_change_percentage_24h': -0.23156,
#   'circulating_supply': 3267198860.635922,
#   'total_supply': 3267198860.635922,
#   'max_supply': None,
#   'ath': 1.22,
#   'ath_change_percentage': -17.9803,
#   'ath_date': '2020-03-13T03:02:50.373Z',
#   'atl': 0.88196,
#   'atl_change_percentage': 13.35699,
#   'atl_date': '2023-03-11T07:50:50.514Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:24.833Z'},
#  {'id': 'ethena-staked-usde',
#   'symbol': 'susde',
#   'name': 'Ethena Staked USDe',
#   'image': 'https://coin-images.coingecko.com/coins/images/33669/large/sUSDe-Symbol-Color.png?1716307680',
#   'current_price': 1.16,
#   'market_cap': 3166286675,
#   'market_cap_rank': 42,
#   'fully_diluted_valuation': 3166286675,
#   'total_volume': 16451485,
#   'high_24h': 1.16,
#   'low_24h': 1.16,
#   'price_change_24h': 0.00041807,
#   'price_change_percentage_24h': 0.03606,
#   'market_cap_change_24h': -46947017.33524752,
#   'market_cap_change_percentage_24h': -1.46105,
#   'circulating_supply': 2728933652.208124,
#   'total_supply': 2728933652.208124,
#   'max_supply': None,
#   'ath': 1.29,
#   'ath_change_percentage': -10.15793,
#   'ath_date': '2025-01-29T17:52:32.991Z',
#   'atl': 1.012,
#   'atl_change_percentage': 14.57303,
#   'atl_date': '2024-04-03T14:23:03.162Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:25.444Z'},
#  {'id': 'okb',
#   'symbol': 'okb',
#   'name': 'OKB',
#   'image': 'https://coin-images.coingecko.com/coins/images/4463/large/WeChat_Image_20220118095654.png?1696505053',
#   'current_price': 50.93,
#   'market_cap': 3056534423,
#   'market_cap_rank': 43,
#   'fully_diluted_valuation': 12020213126,
#   'total_volume': 8344506,
#   'high_24h': 50.96,
#   'low_24h': 49.82,
#   'price_change_24h': 0.156838,
#   'price_change_percentage_24h': 0.30889,
#   'market_cap_change_24h': 7068979,
#   'market_cap_change_percentage_24h': 0.23181,
#   'circulating_supply': 60000000.0,
#   'total_supply': 235957685.3,
#   'max_supply': 300000000.0,
#   'ath': 73.8,
#   'ath_change_percentage': -30.9757,
#   'ath_date': '2024-03-14T00:30:12.502Z',
#   'atl': 0.580608,
#   'atl_change_percentage': 8673.94743,
#   'atl_date': '2019-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:31.747Z'},
#  {'id': 'internet-computer',
#   'symbol': 'icp',
#   'name': 'Internet Computer',
#   'image': 'https://coin-images.coingecko.com/coins/images/14495/large/Internet_Computer_logo.png?1696514180',
#   'current_price': 6.2,
#   'market_cap': 2987092621,
#   'market_cap_rank': 44,
#   'fully_diluted_valuation': 3290048783,
#   'total_volume': 61555356,
#   'high_24h': 6.21,
#   'low_24h': 5.96,
#   'price_change_24h': 0.150287,
#   'price_change_percentage_24h': 2.48481,
#   'market_cap_change_24h': 70968552,
#   'market_cap_change_percentage_24h': 2.43366,
#   'circulating_supply': 481908182.4292024,
#   'total_supply': 530784153.7162618,
#   'max_supply': None,
#   'ath': 700.65,
#   'ath_change_percentage': -99.11548,
#   'ath_date': '2021-05-10T16:05:53.653Z',
#   'atl': 2.87,
#   'atl_change_percentage': 116.31031,
#   'atl_date': '2023-09-22T00:29:57.369Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:30.054Z'},
#  {'id': 'gatechain-token',
#   'symbol': 'gt',
#   'name': 'Gate',
#   'image': 'https://coin-images.coingecko.com/coins/images/8183/large/200X200.png?1735246724',
#   'current_price': 23.94,
#   'market_cap': 2939611643,
#   'market_cap_rank': 45,
#   'fully_diluted_valuation': 7175000210,
#   'total_volume': 11072105,
#   'high_24h': 24.02,
#   'low_24h': 23.67,
#   'price_change_24h': 0.109124,
#   'price_change_percentage_24h': 0.45789,
#   'market_cap_change_24h': 9113025,
#   'market_cap_change_percentage_24h': 0.31097,
#   'circulating_supply': 122910587.76765741,
#   'total_supply': 300000000.0,
#   'max_supply': None,
#   'ath': 25.94,
#   'ath_change_percentage': -7.7623,
#   'ath_date': '2025-01-25T03:07:37.823Z',
#   'atl': 0.25754,
#   'atl_change_percentage': 9190.17122,
#   'atl_date': '2020-03-13T02:18:02.481Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:27.197Z'},
#  {'id': 'ondo-finance',
#   'symbol': 'ondo',
#   'name': 'Ondo',
#   'image': 'https://coin-images.coingecko.com/coins/images/26580/large/ONDO.png?1696525656',
#   'current_price': 0.914911,
#   'market_cap': 2907694046,
#   'market_cap_rank': 46,
#   'fully_diluted_valuation': 9204162947,
#   'total_volume': 167706213,
#   'high_24h': 0.939258,
#   'low_24h': 0.870589,
#   'price_change_24h': 0.02834423,
#   'price_change_percentage_24h': 3.19708,
#   'market_cap_change_24h': 111176840,
#   'market_cap_change_percentage_24h': 3.97555,
#   'circulating_supply': 3159107529.0,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 2.14,
#   'ath_change_percentage': -57.15941,
#   'ath_date': '2024-12-16T00:36:00.777Z',
#   'atl': 0.082171,
#   'atl_change_percentage': 1015.7899,
#   'atl_date': '2024-01-18T12:14:30.524Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:32.218Z'},
#  {'id': 'mantle',
#   'symbol': 'mnt',
#   'name': 'Mantle',
#   'image': 'https://coin-images.coingecko.com/coins/images/30980/large/Mantle-Logo-mark.png?1739213200',
#   'current_price': 0.844015,
#   'market_cap': 2843207392,
#   'market_cap_rank': 47,
#   'fully_diluted_valuation': 5255397808,
#   'total_volume': 143647937,
#   'high_24h': 0.847358,
#   'low_24h': 0.835486,
#   'price_change_24h': 0.00121456,
#   'price_change_percentage_24h': 0.14411,
#   'market_cap_change_24h': 8160259,
#   'market_cap_change_percentage_24h': 0.28784,
#   'circulating_supply': 3364694382.83684,
#   'total_supply': 6219316794.99,
#   'max_supply': 6219316794.99,
#   'ath': 1.54,
#   'ath_change_percentage': -45.11759,
#   'ath_date': '2024-04-08T09:45:25.482Z',
#   'atl': 0.307978,
#   'atl_change_percentage': 174.20276,
#   'atl_date': '2023-10-18T02:50:46.942Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:31.087Z'},
#  {'id': 'tokenize-xchange',
#   'symbol': 'tkx',
#   'name': 'Tokenize Xchange',
#   'image': 'https://coin-images.coingecko.com/coins/images/4984/large/TKX_-_Logo_-_RGB-15.png?1696505519',
#   'current_price': 35.18,
#   'market_cap': 2818124350,
#   'market_cap_rank': 49,
#   'fully_diluted_valuation': 3522831621,
#   'total_volume': 20999551,
#   'high_24h': 35.41,
#   'low_24h': 34.66,
#   'price_change_24h': 0.02396768,
#   'price_change_percentage_24h': 0.06818,
#   'market_cap_change_24h': -1337365.9978661537,
#   'market_cap_change_percentage_24h': -0.04743,
#   'circulating_supply': 79995999.05112354,
#   'total_supply': 100000000.0,
#   'max_supply': 100000000.0,
#   'ath': 50.43,
#   'ath_change_percentage': -30.14598,
#   'ath_date': '2025-01-03T19:12:43.038Z',
#   'atl': 0.111255,
#   'atl_change_percentage': 31564.56926,
#   'atl_date': '2019-04-28T00:00:00.000Z',
#   'roi': {'times': 120.09000618871845,
#    'currency': 'usd',
#    'percentage': 12009.000618871845},
#   'last_updated': '2025-03-26T00:13:36.194Z'},
#  {'id': 'aave',
#   'symbol': 'aave',
#   'name': 'Aave',
#   'image': 'https://coin-images.coingecko.com/coins/images/12645/large/aave-token-round.png?1720472354',
#   'current_price': 186.37,
#   'market_cap': 2812168021,
#   'market_cap_rank': 48,
#   'fully_diluted_valuation': 2981428766,
#   'total_volume': 210860786,
#   'high_24h': 192.17,
#   'low_24h': 185.8,
#   'price_change_24h': -4.496217390357145,
#   'price_change_percentage_24h': -2.35572,
#   'market_cap_change_24h': -64056863.95836544,
#   'market_cap_change_percentage_24h': -2.22712,
#   'circulating_supply': 15091652.988081245,
#   'total_supply': 16000000.0,
#   'max_supply': 16000000.0,
#   'ath': 661.69,
#   'ath_change_percentage': -71.79387,
#   'ath_date': '2021-05-18T21:19:59.514Z',
#   'atl': 26.02,
#   'atl_change_percentage': 617.19669,
#   'atl_date': '2020-11-05T09:20:11.928Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:34.370Z'},
#  {'id': 'coinbase-wrapped-btc',
#   'symbol': 'cbbtc',
#   'name': 'Coinbase Wrapped BTC',
#   'image': 'https://coin-images.coingecko.com/coins/images/40143/large/cbbtc.webp?1726136727',
#   'current_price': 87334,
#   'market_cap': 2787009081,
#   'market_cap_rank': 50,
#   'fully_diluted_valuation': 2787009081,
#   'total_volume': 249048475,
#   'high_24h': 88441,
#   'low_24h': 86372,
#   'price_change_24h': -63.56471322516154,
#   'price_change_percentage_24h': -0.07273,
#   'market_cap_change_24h': 49203626,
#   'market_cap_change_percentage_24h': 1.79719,
#   'circulating_supply': 31840.13472243,
#   'total_supply': 31840.13472243,
#   'max_supply': None,
#   'ath': 108953,
#   'ath_change_percentage': -19.83368,
#   'ath_date': '2025-01-20T09:20:53.854Z',
#   'atl': 57439,
#   'atl_change_percentage': 52.06365,
#   'atl_date': '2024-09-12T14:07:41.775Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:23.312Z'},
#  {'id': 'ethereum-classic',
#   'symbol': 'etc',
#   'name': 'Ethereum Classic',
#   'image': 'https://coin-images.coingecko.com/coins/images/453/large/ethereum-classic-logo.png?1696501717',
#   'current_price': 18.44,
#   'market_cap': 2786622980,
#   'market_cap_rank': 51,
#   'fully_diluted_valuation': 2786642629,
#   'total_volume': 66891667,
#   'high_24h': 18.64,
#   'low_24h': 18.04,
#   'price_change_24h': 0.079915,
#   'price_change_percentage_24h': 0.43537,
#   'market_cap_change_24h': 17972349,
#   'market_cap_change_percentage_24h': 0.64914,
#   'circulating_supply': 151260617.0327686,
#   'total_supply': 151261683.5927686,
#   'max_supply': 210700000.0,
#   'ath': 167.09,
#   'ath_change_percentage': -88.97208,
#   'ath_date': '2021-05-06T18:34:22.133Z',
#   'atl': 0.615038,
#   'atl_change_percentage': 2895.91886,
#   'atl_date': '2016-07-25T00:00:00.000Z',
#   'roi': {'times': 39.968320511896955,
#    'currency': 'usd',
#    'percentage': 3996.8320511896954},
#   'last_updated': '2025-03-26T00:13:26.205Z'},
#  {'id': 'first-digital-usd',
#   'symbol': 'fdusd',
#   'name': 'First Digital USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/31079/large/FDUSD_icon_black.png?1731097953',
#   'current_price': 0.997904,
#   'market_cap': 2456430563,
#   'market_cap_rank': 52,
#   'fully_diluted_valuation': 2456430563,
#   'total_volume': 5005995311,
#   'high_24h': 1.004,
#   'low_24h': 0.994255,
#   'price_change_24h': -0.002523213156639614,
#   'price_change_percentage_24h': -0.25221,
#   'market_cap_change_24h': -2645070.3392391205,
#   'market_cap_change_percentage_24h': -0.10756,
#   'circulating_supply': 2460156654.257888,
#   'total_supply': 2460156654.257888,
#   'max_supply': None,
#   'ath': 1.15,
#   'ath_change_percentage': -13.32514,
#   'ath_date': '2025-02-03T02:30:49.959Z',
#   'atl': 0.940377,
#   'atl_change_percentage': 6.11869,
#   'atl_date': '2024-12-05T22:30:51.394Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:26.853Z'},
#  {'id': 'official-trump',
#   'symbol': 'trump',
#   'name': 'Official Trump',
#   'image': 'https://coin-images.coingecko.com/coins/images/53746/large/trump.png?1737171561',
#   'current_price': 11.58,
#   'market_cap': 2320686050,
#   'market_cap_rank': 53,
#   'fully_diluted_valuation': 11603431576,
#   'total_volume': 501409478,
#   'high_24h': 11.87,
#   'low_24h': 11.35,
#   'price_change_24h': -0.2227819003181022,
#   'price_change_percentage_24h': -1.88772,
#   'market_cap_change_24h': -55606787.44619942,
#   'market_cap_change_percentage_24h': -2.34006,
#   'circulating_supply': 199999977.136,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 73.43,
#   'ath_change_percentage': -84.25103,
#   'ath_date': '2025-01-19T11:50:34.806Z',
#   'atl': 4.29,
#   'atl_change_percentage': 169.52795,
#   'atl_date': '2025-01-18T03:40:29.231Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:32.932Z'},
#  {'id': 'bittensor',
#   'symbol': 'tao',
#   'name': 'Bittensor',
#   'image': 'https://coin-images.coingecko.com/coins/images/28452/large/ARUsPeNQ_400x400.jpeg?1696527447',
#   'current_price': 269.23,
#   'market_cap': 2296716673,
#   'market_cap_rank': 54,
#   'fully_diluted_valuation': 5665534930,
#   'total_volume': 72324051,
#   'high_24h': 273.9,
#   'low_24h': 262.93,
#   'price_change_24h': -0.040610949710355726,
#   'price_change_percentage_24h': -0.01508,
#   'market_cap_change_24h': 16545256,
#   'market_cap_change_percentage_24h': 0.72561,
#   'circulating_supply': 8513062.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 757.6,
#   'ath_change_percentage': -64.42832,
#   'ath_date': '2024-03-07T18:45:36.466Z',
#   'atl': 30.83,
# ...
#   'total_volume': 23054695,
#   'high_24h': 80.15,
#   'low_24h': 77.76,
#   'price_change_24h': -0.42754979164142526,
#   'price_change_percentage_24h': -0.53497,
#   'market_cap_change_24h': -2802256.174391508,
#   'market_cap_change_percentage_24h': -0.24234,
#   'circulating_supply': 14544176.164091088,
#   'total_supply': 14612493.0,
#   'max_supply': 14612493.0,
#   'ath': 427.42,
#   'ath_change_percentage': -81.44373,
#   'ath_date': '2021-09-11T09:15:00.668Z',
#   'atl': 0.215773,
#   'atl_change_percentage': 36657.84912,
#   'atl_date': '2018-08-23T00:00:00.000Z',
#   'roi': {'times': 15.560062636992662,
#    'currency': 'eth',
#    'percentage': 1556.0062636992661},
#   'last_updated': '2025-03-26T00:13:33.245Z'},
#  {'id': 'binance-staked-sol',
#   'symbol': 'bnsol',
#   'name': 'Binance Staked SOL',
#   'image': 'https://coin-images.coingecko.com/coins/images/40132/large/bnsol.png?1725968367',
#   'current_price': 149.64,
#   'market_cap': 1140581967,
#   'market_cap_rank': 84,
#   'fully_diluted_valuation': 1140581967,
#   'total_volume': 3939417,
#   'high_24h': 153.82,
#   'low_24h': 144.22,
#   'price_change_24h': 2.52,
#   'price_change_percentage_24h': 1.71149,
#   'market_cap_change_24h': 38101520,
#   'market_cap_change_percentage_24h': 3.45598,
#   'circulating_supply': 7603105.285043372,
#   'total_supply': 7603105.285043372,
#   'max_supply': None,
#   'ath': 297.96,
#   'ath_change_percentage': -49.79374,
#   'ath_date': '2025-01-19T11:30:53.744Z',
#   'atl': 118.29,
#   'atl_change_percentage': 26.45865,
#   'atl_date': '2025-03-11T01:11:46.882Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:36.072Z'},
#  {'id': 'worldcoin-wld',
#   'symbol': 'wld',
#   'name': 'Worldcoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/31069/large/worldcoin.jpeg?1696529903',
#   'current_price': 0.9325,
#   'market_cap': 1118520166,
#   'market_cap_rank': 85,
#   'fully_diluted_valuation': 9328992165,
#   'total_volume': 132920597,
#   'high_24h': 0.942646,
#   'low_24h': 0.903596,
#   'price_change_24h': 0.02890425,
#   'price_change_percentage_24h': 3.1988,
#   'market_cap_change_24h': 41300619,
#   'market_cap_change_percentage_24h': 3.834,
#   'circulating_supply': 1198972135.817049,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 11.74,
#   'ath_change_percentage': -92.05565,
#   'ath_date': '2024-03-10T00:10:42.330Z',
#   'atl': 0.708589,
#   'atl_change_percentage': 31.63007,
#   'atl_date': '2025-03-11T01:11:28.418Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:31.250Z'},
#  {'id': 'maker',
#   'symbol': 'mkr',
#   'name': 'Maker',
#   'image': 'https://coin-images.coingecko.com/coins/images/1364/large/Mark_Maker.png?1696502423',
#   'current_price': 1292.32,
#   'market_cap': 1095136968,
#   'market_cap_rank': 86,
#   'fully_diluted_valuation': 1129006951,
#   'total_volume': 45885273,
#   'high_24h': 1292.48,
#   'low_24h': 1257.96,
#   'price_change_24h': 13.45,
#   'price_change_percentage_24h': 1.05155,
#   'market_cap_change_24h': 15877353,
#   'market_cap_change_percentage_24h': 1.47113,
#   'circulating_supply': 847663.1970765893,
#   'total_supply': 873879.4050586025,
#   'max_supply': 1005577.0,
#   'ath': 6292.31,
#   'ath_change_percentage': -79.46458,
#   'ath_date': '2021-05-03T21:54:29.333Z',
#   'atl': 168.36,
#   'atl_change_percentage': 667.50518,
#   'atl_date': '2020-03-16T20:52:36.527Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:31.597Z'},
#  {'id': 'bonk',
#   'symbol': 'bonk',
#   'name': 'Bonk',
#   'image': 'https://coin-images.coingecko.com/coins/images/28600/large/bonk.jpg?1696527587',
#   'current_price': 1.394e-05,
#   'market_cap': 1085908868,
#   'market_cap_rank': 87,
#   'fully_diluted_valuation': 1246247124,
#   'total_volume': 97366503,
#   'high_24h': 1.429e-05,
#   'low_24h': 1.359e-05,
#   'price_change_24h': -2.55342402319e-07,
#   'price_change_percentage_24h': -1.79819,
#   'market_cap_change_24h': -5714356.134785652,
#   'market_cap_change_percentage_24h': -0.52347,
#   'circulating_supply': 77419592329436.58,
#   'total_supply': 88850866881178.2,
#   'max_supply': 88850866881178.2,
#   'ath': 5.825e-05,
#   'ath_change_percentage': -75.96606,
#   'ath_date': '2024-11-20T04:01:06.465Z',
#   'atl': 8.6142e-08,
#   'atl_change_percentage': 16151.92689,
#   'atl_date': '2022-12-29T22:48:46.755Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:22.541Z'},
#  {'id': 'blockstack',
#   'symbol': 'stx',
#   'name': 'Stacks',
#   'image': 'https://coin-images.coingecko.com/coins/images/2069/large/Stacks_Logo_png.png?1709979332',
#   'current_price': 0.69859,
#   'market_cap': 1062414933,
#   'market_cap_rank': 88,
#   'fully_diluted_valuation': 1062414933,
#   'total_volume': 41807578,
#   'high_24h': 0.708034,
#   'low_24h': 0.676466,
#   'price_change_24h': 0.01160233,
#   'price_change_percentage_24h': 1.68887,
#   'market_cap_change_24h': 22589577,
#   'market_cap_change_percentage_24h': 2.17244,
#   'circulating_supply': 1518559103.62663,
#   'total_supply': 1518559103.62663,
#   'max_supply': 1818000000.0,
#   'ath': 3.86,
#   'ath_change_percentage': -81.8848,
#   'ath_date': '2024-04-01T12:34:58.342Z',
#   'atl': 0.04559639,
#   'atl_change_percentage': 1435.27408,
#   'atl_date': '2020-03-13T02:29:26.415Z',
#   'roi': {'times': 4.821580859375443,
#    'currency': 'usd',
#    'percentage': 482.15808593754423},
#   'last_updated': '2025-03-26T00:13:22.209Z'},
#  {'id': 'injective-protocol',
#   'symbol': 'inj',
#   'name': 'Injective',
#   'image': 'https://coin-images.coingecko.com/coins/images/12882/large/Other_200x200.png?1738782212',
#   'current_price': 10.64,
#   'market_cap': 1038285335,
#   'market_cap_rank': 89,
#   'fully_diluted_valuation': 1062432075,
#   'total_volume': 82016328,
#   'high_24h': 10.79,
#   'low_24h': 10.25,
#   'price_change_24h': 0.152861,
#   'price_change_percentage_24h': 1.45798,
#   'market_cap_change_24h': 14140524,
#   'market_cap_change_percentage_24h': 1.38072,
#   'circulating_supply': 97727220.33,
#   'total_supply': 100000000.0,
#   'max_supply': None,
#   'ath': 52.62,
#   'ath_change_percentage': -79.74599,
#   'ath_date': '2024-03-14T15:06:22.124Z',
#   'atl': 0.657401,
#   'atl_change_percentage': 1521.20233,
#   'atl_date': '2020-11-03T16:19:30.576Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:29.989Z'},
#  {'id': 'sei-network',
#   'symbol': 'sei',
#   'name': 'Sei',
#   'image': 'https://coin-images.coingecko.com/coins/images/28205/large/Sei_Logo_-_Transparent.png?1696527207',
#   'current_price': 0.207578,
#   'market_cap': 1015824411,
#   'market_cap_rank': 90,
#   'fully_diluted_valuation': 2080600734,
#   'total_volume': 74340639,
#   'high_24h': 0.209814,
#   'low_24h': 0.1989,
#   'price_change_24h': 0.00528871,
#   'price_change_percentage_24h': 2.61442,
#   'market_cap_change_24h': 29824700,
#   'market_cap_change_percentage_24h': 3.02482,
#   'circulating_supply': 4882361111.0,
#   'total_supply': 10000000000.0,
#   'max_supply': None,
#   'ath': 1.14,
#   'ath_change_percentage': -81.76287,
#   'ath_date': '2024-03-16T02:30:23.904Z',
#   'atl': 0.095364,
#   'atl_change_percentage': 117.95684,
#   'atl_date': '2023-10-19T08:05:30.655Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:33.575Z'},
#  {'id': 'stargate-bridged-usdc-berachain',
#   'symbol': 'usdc.e',
#   'name': 'Stargate Bridged USDC (Berachain)',
#   'image': 'https://coin-images.coingecko.com/coins/images/54336/large/usdc.jpg?1739335056',
#   'current_price': 0.998528,
#   'market_cap': 1015059286,
#   'market_cap_rank': 92,
#   'fully_diluted_valuation': 1015059286,
#   'total_volume': 13530834,
#   'high_24h': 1.003,
#   'low_24h': 0.994887,
#   'price_change_24h': 0.00133004,
#   'price_change_percentage_24h': 0.13338,
#   'market_cap_change_24h': 114140608,
#   'market_cap_change_percentage_24h': 12.66936,
#   'circulating_supply': 1015561587.309781,
#   'total_supply': 1015561587.309781,
#   'max_supply': None,
#   'ath': 1.031,
#   'ath_change_percentage': -2.94985,
#   'ath_date': '2025-02-28T16:53:22.940Z',
#   'atl': 0.97659,
#   'atl_change_percentage': 2.43542,
#   'atl_date': '2025-03-07T00:19:25.911Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:34.078Z'},
#  {'id': 'rocket-pool-eth',
#   'symbol': 'reth',
#   'name': 'Rocket Pool ETH',
#   'image': 'https://coin-images.coingecko.com/coins/images/20764/large/reth.png?1696520159',
#   'current_price': 2334.14,
#   'market_cap': 1013377114,
#   'market_cap_rank': 91,
#   'fully_diluted_valuation': 1013377114,
#   'total_volume': 3515589,
#   'high_24h': 2366.16,
#   'low_24h': 2308.81,
#   'price_change_24h': -22.0666168919588,
#   'price_change_percentage_24h': -0.93653,
#   'market_cap_change_24h': -9610503.026122093,
#   'market_cap_change_percentage_24h': -0.93945,
#   'circulating_supply': 434163.4287555599,
#   'total_supply': 434163.4287555599,
#   'max_supply': None,
#   'ath': 4814.31,
#   'ath_change_percentage': -51.45141,
#   'ath_date': '2021-12-01T08:03:50.749Z',
#   'atl': 887.26,
#   'atl_change_percentage': 163.42565,
#   'atl_date': '2022-06-18T20:55:45.957Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:33.413Z'},
#  {'id': 'dexe',
#   'symbol': 'dexe',
#   'name': 'DeXe',
#   'image': 'https://coin-images.coingecko.com/coins/images/12713/large/DEXE_token_logo.png?1696512514',
#   'current_price': 17.56,
#   'market_cap': 1002488021,
#   'market_cap_rank': 93,
#   'fully_diluted_valuation': 1694191068,
#   'total_volume': 8554639,
#   'high_24h': 17.65,
#   'low_24h': 17.25,
#   'price_change_24h': 0.161844,
#   'price_change_percentage_24h': 0.93045,
#   'market_cap_change_24h': 10744834,
#   'market_cap_change_percentage_24h': 1.08343,
#   'circulating_supply': 57103774.56313077,
#   'total_supply': 96504599.33609451,
#   'max_supply': None,
#   'ath': 32.38,
#   'ath_change_percentage': -45.93572,
#   'ath_date': '2021-03-08T13:29:57.935Z',
#   'atl': 0.671563,
#   'atl_change_percentage': 2506.83238,
#   'atl_date': '2020-11-06T19:31:40.144Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:24.293Z'},
#  {'id': 'the-graph',
#   'symbol': 'grt',
#   'name': 'The Graph',
#   'image': 'https://coin-images.coingecko.com/coins/images/13397/large/Graph_Token.png?1696513159',
#   'current_price': 0.104499,
#   'market_cap': 999073058,
#   'market_cap_rank': 94,
#   'fully_diluted_valuation': 1128760423,
#   'total_volume': 37259638,
#   'high_24h': 0.105959,
#   'low_24h': 0.100705,
#   'price_change_24h': 0.00285052,
#   'price_change_percentage_24h': 2.80429,
#   'market_cap_change_24h': 23682000,
#   'market_cap_change_percentage_24h': 2.42795,
#   'circulating_supply': 9548531509.16547,
#   'total_supply': 10788004319.0,
#   'max_supply': 10788004319.0,
#   'ath': 2.84,
#   'ath_change_percentage': -96.32132,
#   'ath_date': '2021-02-12T07:28:45.775Z',
#   'atl': 0.052051,
#   'atl_change_percentage': 100.82209,
#   'atl_date': '2022-11-22T10:05:03.503Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:29.883Z'},
#  {'id': 'theta-token',
#   'symbol': 'theta',
#   'name': 'Theta Network',
#   'image': 'https://coin-images.coingecko.com/coins/images/2538/large/theta-token-logo.png?1696503349',
#   'current_price': 0.991617,
#   'market_cap': 992532563,
#   'market_cap_rank': 95,
#   'fully_diluted_valuation': 992532563,
#   'total_volume': 17396057,
#   'high_24h': 0.994649,
#   'low_24h': 0.964087,
#   'price_change_24h': 0.00810068,
#   'price_change_percentage_24h': 0.82364,
#   'market_cap_change_24h': 14100190,
#   'market_cap_change_percentage_24h': 1.4411,
#   'circulating_supply': 1000000000.0,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 15.72,
#   'ath_change_percentage': -93.67422,
#   'ath_date': '2021-04-16T13:15:11.190Z',
#   'atl': 0.04039979,
#   'atl_change_percentage': 2361.38455,
#   'atl_date': '2020-03-13T02:24:16.483Z',
#   'roi': {'times': 5.610781150885713,
#    'currency': 'usd',
#    'percentage': 561.0781150885713},
#   'last_updated': '2025-03-26T00:13:36.191Z'},
#  {'id': 'lido-dao',
#   'symbol': 'ldo',
#   'name': 'Lido DAO',
#   'image': 'https://coin-images.coingecko.com/coins/images/13573/large/Lido_DAO.png?1696513326',
#   'current_price': 1.056,
#   'market_cap': 951147873,
#   'market_cap_rank': 96,
#   'fully_diluted_valuation': 1059329524,
#   'total_volume': 70487274,
#   'high_24h': 1.084,
#   'low_24h': 1.05,
#   'price_change_24h': -0.014042532068253344,
#   'price_change_percentage_24h': -1.31225,
#   'market_cap_change_24h': -10765112.1479491,
#   'market_cap_change_percentage_24h': -1.11914,
#   'circulating_supply': 897877243.8587132,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 7.3,
#   'ath_change_percentage': -85.50609,
#   'ath_date': '2021-08-20T08:35:20.158Z',
#   'atl': 0.40615,
#   'atl_change_percentage': 160.61117,
#   'atl_date': '2022-06-18T20:55:12.035Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:30.679Z'},
#  {'id': 'usual-usd',
#   'symbol': 'usd0',
#   'name': 'Usual USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/38272/large/USD0LOGO.png?1716962811',
#   'current_price': 0.997798,
#   'market_cap': 951014904,
#   'market_cap_rank': 97,
#   'fully_diluted_valuation': 951014904,
#   'total_volume': 34179729,
#   'high_24h': 0.998231,
#   'low_24h': 0.997576,
#   'price_change_24h': -0.000175850425984225,
#   'price_change_percentage_24h': -0.01762,
#   'market_cap_change_24h': 1390218,
#   'market_cap_change_percentage_24h': 0.1464,
#   'circulating_supply': 952963421.8954352,
#   'total_supply': 952963421.8954352,
#   'max_supply': None,
#   'ath': 1.33,
#   'ath_change_percentage': -24.73536,
#   'ath_date': '2024-07-12T08:28:59.311Z',
#   'atl': 0.976415,
#   'atl_change_percentage': 2.18847,
#   'atl_date': '2025-01-20T17:07:15.786Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:29.449Z'},
#  {'id': 'flare-networks',
#   'symbol': 'flr',
#   'name': 'Flare',
#   'image': 'https://coin-images.coingecko.com/coins/images/28624/large/FLR-icon200x200.png?1696527609',
#   'current_price': 0.01456647,
#   'market_cap': 892699909,
#   'market_cap_rank': 98,
#   'fully_diluted_valuation': 1508027002,
#   'total_volume': 5813659,
#   'high_24h': 0.01484405,
#   'low_24h': 0.01443306,
#   'price_change_24h': -7.0666196889675e-05,
#   'price_change_percentage_24h': -0.48279,
#   'market_cap_change_24h': -3086600.9123846292,
#   'market_cap_change_percentage_24h': -0.34457,
#   'circulating_supply': 61094354272.3454,
#   'total_supply': 103205942958.4257,
#   'max_supply': None,
#   'ath': 0.150073,
#   'ath_change_percentage': -90.28032,
#   'ath_date': '2023-01-10T03:14:05.921Z',
#   'atl': 0.00827405,
#   'atl_change_percentage': 76.29343,
#   'atl_date': '2023-10-19T03:35:41.663Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:26.923Z'},
#  {'id': 'berachain-bera',
#   'symbol': 'bera',
#   'name': 'Berachain',
#   'image': 'https://coin-images.coingecko.com/coins/images/25235/large/BERA.png?1738822008',
#   'current_price': 8.02,
#   'market_cap': 870905335,
#   'market_cap_rank': 99,
#   'fully_diluted_valuation': 4036476088,
#   'total_volume': 200205240,
#   'high_24h': 8.25,
#   'low_24h': 7.53,
#   'price_change_24h': 0.04149899,
#   'price_change_percentage_24h': 0.52038,
#   'market_cap_change_24h': 8630990,
#   'market_cap_change_percentage_24h': 1.00096,
#   'circulating_supply': 107989297.5953384,
#   'total_supply': 500509297.5953384,
#   'max_supply': None,
#   'ath': 14.83,
#   'ath_change_percentage': -45.87981,
#   'ath_date': '2025-02-06T14:16:01.862Z',
#   'atl': 4.79,
#   'atl_change_percentage': 67.578,
#   'atl_date': '2025-02-10T03:01:22.311Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:36.207Z'},
#  {'id': 'eos',
#   'symbol': 'eos',
#   'name': 'EOS',
#   'image': 'https://coin-images.coingecko.com/coins/images/738/large/CG_EOS_Icon.png?1731705232',
#   'current_price': 0.571621,
#   'market_cap': 866720554,
#   'market_cap_rank': 100,
#   'fully_diluted_valuation': 1199901255,
#   'total_volume': 97524478,
#   'high_24h': 0.581257,
#   'low_24h': 0.566671,
#   'price_change_24h': -0.001150568575923328,
#   'price_change_percentage_24h': -0.20088,
#   'market_cap_change_24h': 803748,
#   'market_cap_change_percentage_24h': 0.09282,
#   'circulating_supply': 1516885789.1746,
#   'total_supply': 2100000000.0,
#   'max_supply': 2100000000.0,
#   'ath': 22.71,
#   'ath_change_percentage': -97.48339,
#   'ath_date': '2018-04-29T07:50:33.540Z',
#   'atl': 0.402746,
#   'atl_change_percentage': 41.91432,
#   'atl_date': '2024-11-04T21:55:59.771Z',
#   'roi': {'times': -0.42260481225330093,
#    'currency': 'usd',
#    'percentage': -42.26048122533009},
#   'last_updated': '2025-03-26T00:13:26.876Z'}]

# %% [markdown]
# ### Split into Json Type Chunks

# %%
from langchain_text_splitters import RecursiveJsonSplitter

json_splitter = RecursiveJsonSplitter(max_chunk_size=200)
json_chunks = json_splitter.split_json(json_data[0])
json_chunks
# Out:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/1/large/bitcoin.png?1696501400',
#   'current_price': 87326,
#   'market_cap': 1734666709251},
#  {'market_cap_rank': 1,
#   'fully_diluted_valuation': 1734666709251,
#   'total_volume': 30331812936,
#   'high_24h': 88430,
#   'low_24h': 86358,
#   'price_change_24h': -58.09211586951278},
#  {'price_change_percentage_24h': -0.06648,
#   'market_cap_change_24h': -1343300292.4060059,
#   'market_cap_change_percentage_24h': -0.07738,
#   'circulating_supply': 19841981.0,
#   'total_supply': 19841981.0},
#  {'max_supply': 21000000.0,
#   'ath': 108786,
#   'ath_change_percentage': -19.60573,
#   'ath_date': '2025-01-20T09:11:54.494Z',
#   'atl': 67.81,
#   'atl_change_percentage': 128876.00034},
#  {'atl_date': '2013-07-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2025-03-26T00:13:33.113Z'}]

# %% [markdown]
# Notice that the chunks are not in Document Type

# %% [markdown]
# ### The Splitter can also Convert to Document Type to extract more information.

# %%
docs = json_splitter.create_documents(texts=[json_data[0]])
docs
# Out:
# [Document(metadata={}, page_content='{"id": "bitcoin", "symbol": "btc", "name": "Bitcoin", "image": "https://coin-images.coingecko.com/coins/images/1/large/bitcoin.png?1696501400", "current_price": 87326, "market_cap": 1734666709251}'),
#  Document(metadata={}, page_content='{"market_cap_rank": 1, "fully_diluted_valuation": 1734666709251, "total_volume": 30331812936, "high_24h": 88430, "low_24h": 86358, "price_change_24h": -58.09211586951278}'),
#  Document(metadata={}, page_content='{"price_change_percentage_24h": -0.06648, "market_cap_change_24h": -1343300292.4060059, "market_cap_change_percentage_24h": -0.07738, "circulating_supply": 19841981.0, "total_supply": 19841981.0}'),
#  Document(metadata={}, page_content='{"max_supply": 21000000.0, "ath": 108786, "ath_change_percentage": -19.60573, "ath_date": "2025-01-20T09:11:54.494Z", "atl": 67.81, "atl_change_percentage": 128876.00034}'),
#  Document(metadata={}, page_content='{"atl_date": "2013-07-06T00:00:00.000Z", "roi": null, "last_updated": "2025-03-26T00:13:33.113Z"}')]

# %% [markdown]
# Now Json splitted into Document Chunks

# %% [markdown]
# ### If we want to convert the output into String

# %%
text = json_splitter.split_text(json_data[0])
text
# Out:
# ['{"id": "bitcoin", "symbol": "btc", "name": "Bitcoin", "image": "https://coin-images.coingecko.com/coins/images/1/large/bitcoin.png?1696501400", "current_price": 87326, "market_cap": 1734666709251}',
#  '{"market_cap_rank": 1, "fully_diluted_valuation": 1734666709251, "total_volume": 30331812936, "high_24h": 88430, "low_24h": 86358, "price_change_24h": -58.09211586951278}',
#  '{"price_change_percentage_24h": -0.06648, "market_cap_change_24h": -1343300292.4060059, "market_cap_change_percentage_24h": -0.07738, "circulating_supply": 19841981.0, "total_supply": 19841981.0}',
#  '{"max_supply": 21000000.0, "ath": 108786, "ath_change_percentage": -19.60573, "ath_date": "2025-01-20T09:11:54.494Z", "atl": 67.81, "atl_change_percentage": 128876.00034}',
#  '{"atl_date": "2013-07-06T00:00:00.000Z", "roi": null, "last_updated": "2025-03-26T00:13:33.113Z"}']
